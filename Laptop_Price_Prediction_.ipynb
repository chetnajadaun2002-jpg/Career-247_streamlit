# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/laptop_price.csv",encoding='latin')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# 1              Ultrabook    13.3                                    1440x900
# 2               Notebook    15.6                           Full HD 1920x1080
# 3              Ultrabook    15.4          IPS Panel Retina Display 2880x1800
# 4              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...                  ...     ...                                         ...
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1298            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 2            Intel HD Graphics 620       No OS  1.86kg       575.00
# 3               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1298         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 13 columns]

# %%
df.drop(columns=['laptop_ID'],inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(28)

# %%
df[df.duplicated()]
# Out:
#      Company                                    Product            TypeName  \
# 1275    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1276    Dell                              Inspiron 3567            Notebook
# 1277    Acer                             Aspire ES1-531            Notebook
# 1278    Dell                              Inspiron 3552            Notebook
# 1279  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1280      HP                        Pavilion 15-AW003nv            Notebook
# 1281    Dell                              Inspiron 3567            Notebook
# 1282      HP                           Stream 11-Y000na             Netbook
# 1283    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1284  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1285  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1286  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1287      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1288    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
# 1289    Asus                       ZenBook UX305CA-UBM1           Ultrabook
# 1290    Dell                              Inspiron 3567            Notebook
# 1291    Acer                             Aspire ES1-531            Notebook
# 1292    Dell                              Inspiron 3552            Notebook
# 1293  Lenovo                         IdeaPad Y700-15ISK            Notebook
# 1294      HP                        Pavilion 15-AW003nv            Notebook
# 1295    Dell                              Inspiron 3567            Notebook
# 1296      HP                           Stream 11-Y000na             Netbook
# 1297    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1298  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                         IdeaPad 100S-14IBR            Notebook
# 1301      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus        X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Inches                            ScreenResolution  \
# 1275    13.3                 IPS Panel Full HD 1920x1080
# 1276    15.6                                    1366x768
# 1277    15.6                                    1366x768
# 1278    15.6                                    1366x768
# 1279    15.6                 IPS Panel Full HD 1920x1080
# 1280    15.6                           Full HD 1920x1080
# 1281    15.6                                    1366x768
# 1282    11.6                                    1366x768
# 1283    15.6                                    1366x768
# 1284    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1285    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1286    14.0                                    1366x768
# 1287    15.6                                    1366x768
# 1288    15.6                                    1366x768
# 1289    13.3                 IPS Panel Full HD 1920x1080
# 1290    15.6                                    1366x768
# 1291    15.6                                    1366x768
# 1292    15.6                                    1366x768
# 1293    15.6                 IPS Panel Full HD 1920x1080
# 1294    15.6                           Full HD 1920x1080
# 1295    15.6                                    1366x768
# 1296    11.6                                    1366x768
# 1297    15.6                                    1366x768
# 1298    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300    14.0                                    1366x768
# 1301    15.6                                    1366x768
# 1302    15.6                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1275              Intel Core M 6Y30 0.9GHz   8GB           512GB SSD
# 1276            Intel Core i3 7100U 2.4GHz   6GB             1TB HDD
# 1277  Intel Celeron Dual Core N3060 1.6GHz   4GB           500GB HDD
# 1278  Intel Celeron Dual Core N3050 1.6GHz   2GB           500GB HDD
# 1279           Intel Core i7 6700HQ 2.6GHz   8GB             1TB HDD
# 1280             AMD A9-Series 9410 2.9GHz   6GB        1.0TB Hybrid
# 1281            Intel Core i7 7500U 2.7GHz   8GB             1TB HDD
# 1282  Intel Celeron Dual Core N3060 1.6GHz   2GB  32GB Flash Storage
# 1283            Intel Core i7 6500U 2.5GHz   4GB           500GB HDD
# 1284            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1285            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1286  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1287            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1288  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
# 1289              Intel Core M 6Y30 0.9GHz   8GB           512GB SSD
# 1290            Intel Core i3 7100U 2.4GHz   6GB             1TB HDD
# 1291  Intel Celeron Dual Core N3060 1.6GHz   4GB           500GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz   2GB           500GB HDD
# 1293           Intel Core i7 6700HQ 2.6GHz   8GB             1TB HDD
# 1294             AMD A9-Series 9410 2.9GHz   6GB        1.0TB Hybrid
# 1295            Intel Core i7 7500U 2.7GHz   8GB             1TB HDD
# 1296  Intel Celeron Dual Core N3060 1.6GHz   2GB  32GB Flash Storage
# 1297            Intel Core i7 6500U 2.5GHz   4GB           500GB HDD
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
#
#                           Gpu       OpSys  Weight  Price_euros
# 1275    Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1276    Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1277    Intel HD Graphics 400       Linux   2.4kg       289.00
# 1278        Intel HD Graphics  Windows 10  2.20kg       379.00
# 1279  Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1280       AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1281       AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1282    Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1283      Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1284    Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1285    Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1286        Intel HD Graphics  Windows 10   1.5kg       229.00
# 1287       AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1288        Intel HD Graphics  Windows 10   2.2kg       369.00
# 1289    Intel HD Graphics 515  Windows 10   1.2kg       729.00
# 1290    Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 1291    Intel HD Graphics 400       Linux   2.4kg       289.00
# 1292        Intel HD Graphics  Windows 10  2.20kg       379.00
# 1293  Nvidia GeForce GTX 960M  Windows 10   2.6kg       899.00
# 1294       AMD Radeon R7 M440  Windows 10  2.04kg       549.99
# 1295       AMD Radeon R5 M430       Linux   2.3kg       805.99
# 1296    Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1297      Nvidia GeForce 920M  Windows 10   2.2kg       720.32
# 1298    Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1299    Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1300        Intel HD Graphics  Windows 10   1.5kg       229.00
# 1301       AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302        Intel HD Graphics  Windows 10   2.2kg       369.00

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1275 entries, 0 to 1274
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1275 non-null   object
#  1   Product           1275 non-null   object
#  2   TypeName          1275 non-null   object
#  3   Inches            1275 non-null   float64
#  4   ScreenResolution  1275 non-null   object
#  5   Cpu               1275 non-null   object
#  6   Ram               1275 non-null   object
#  7   Memory            1275 non-null   object
#  8   Gpu               1275 non-null   object
#  9   OpSys             1275 non-null   object
#  10  Weight            1275 non-null   object
#  11  Price_euros       1275 non-null   float64
# dtypes: float64(2), object(10)
# memory usage: 129.5+ KB

# %%
df.sample(5)
# Out:
#      Company                               Product            TypeName  \
# 1174  Lenovo                     IdeaPad 510-15IKB            Notebook
# 635     Asus                          VivoBook Pro            Notebook
# 49      Asus  X751NV-TY001T (N4200/4GB/1TB/GeForce            Notebook
# 523       HP                           ProBook 440            Notebook
# 1067    Dell                         Inspiron 5368  2 in 1 Convertible
#
#       Inches                 ScreenResolution  \
# 1174    15.6                Full HD 1920x1080
# 635     15.6                Full HD 1920x1080
# 49      17.3                         1366x768
# 523     15.6                         1366x768
# 1067    13.3  Full HD / Touchscreen 1920x1080
#
#                                        Cpu  Ram     Memory  \
# 1174            Intel Core i7 7500U 2.7GHz  8GB    1TB HDD
# 635            Intel Core i5 7300HQ 2.5GHz  8GB    1TB HDD
# 49    Intel Pentium Quad Core N4200 1.1GHz  4GB    1TB HDD
# 523               Intel Core i3 6006U 2GHz  4GB  128GB SSD
# 1067            Intel Core i7 6500U 2.5GHz  8GB  256GB SSD
#
#                           Gpu       OpSys  Weight  Price_euros
# 1174     Nvidia GeForce 940MX       No OS   2.2kg       709.00
# 635   Nvidia GeForce GTX 1050  Windows 10  1.99kg       906.62
# 49       Nvidia GeForce 920MX  Windows 10   2.8kg       466.00
# 523     Intel HD Graphics 520  Windows 10  1.63kg       689.00
# 1067    Intel HD Graphics 520  Windows 10  1.62kg       798.01

# %%
df['Price']=round(df['Price_euros']*103.44,-2).astype('int')

# %%
df.drop(columns=['Price_euros'],inplace=True)

# %%
sns.displot(df['Price'],kde=True)

# %%
sns.kdeplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# Right Skewed data : tail jha left side ho

# %%
sns.kdeplot(np.log(df['Price']))
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
# This is normal distribution of Price by applying log

# %%
np.exp(np.log(df['Price']))    # vps normal laane ke liye exponential
# Out:
# 0       138600.0
# 1        93000.0
# 2        59500.0
# 3       262500.0
# 4       186600.0
#           ...
# 1270     66000.0
# 1271    155100.0
# 1272     23700.0
# 1273     79000.0
# 1274     38200.0
# Name: Price, Length: 1275, dtype: float64

# %%
print(df['Company'].value_counts())
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# Google         3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
len(df['Company'].value_counts())
# Out:
# 19

# %%
print(df.groupby('Company')['Company'].count().sort_values(ascending=False))
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Mediacom       7
# Razer          7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Chuwi          3
# Fujitsu        3
# LG             3
# Google         3
# Huawei         2
# Name: Company, dtype: int64

# %%
df.groupby('Company')['Company'].transform('count')
# Out:
# 0        21
# 1        21
# 2       268
# 3        21
# 4        21
#        ...
# 1270    289
# 1271    289
# 1272    289
# 1273    268
# 1274    152
# Name: Company, Length: 1275, dtype: int64

# %%
51/1275
# Out:
# 0.04

# %%
df=df[df.groupby('Company')['Company'].transform('count')>20]

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#      Company                              Product            TypeName  Inches  \
# 0      Apple                          MacBook Pro           Ultrabook    13.3
# 1      Apple                          Macbook Air           Ultrabook    13.3
# 2         HP                               250 G6            Notebook    15.6
# 3      Apple                          MacBook Pro           Ultrabook    15.4
# 4      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1219  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1220  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1221  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1222      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1223    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1219   IPS Panel Full HD / Touchscreen 1920x1080
# 1220  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1221                                    1366x768
# 1222                                    1366x768
# 1223                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 4                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1219            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1220            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1221  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1222            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1223  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight   Price
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg  138600
# 1           Intel HD Graphics 6000       macOS  1.34kg   93000
# 2            Intel HD Graphics 620       No OS  1.86kg   59500
# 3               AMD Radeon Pro 455       macOS  1.83kg  262500
# 4     Intel Iris Plus Graphics 650       macOS  1.37kg  186600
# ...                            ...         ...     ...     ...
# 1219         Intel HD Graphics 520  Windows 10   1.8kg   66000
# 1220         Intel HD Graphics 520  Windows 10   1.3kg  155100
# 1221             Intel HD Graphics  Windows 10   1.5kg   23700
# 1222            AMD Radeon R5 M330  Windows 10  2.19kg   79000
# 1223             Intel HD Graphics  Windows 10   2.2kg   38200
#
# [1224 rows x 12 columns]

# %%
print(df['Company'].value_counts())
# Out:
# Company
# Dell       291
# Lenovo     289
# HP         268
# Asus       152
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
df.groupby('Company')['Price'].mean().sort_values(ascending=False)
# Out:
# Company
# MSI        178837.037037
# Apple      161809.523810
# Toshiba    131143.750000
# Dell       124049.140893
# Asus       116249.342105
# Lenovo     113152.249135
# HP         111747.761194
# Acer        65522.772277
# Name: Price, dtype: float64

# %%
sorted_company_list=df.groupby('Company')['Price'].mean().sort_values(ascending=False).index
sorted_company_list
# Out:
# Index(['MSI', 'Apple', 'Toshiba', 'Dell', 'Asus', 'Lenovo', 'HP', 'Acer'], dtype='object', name='Company')

# %%
sorted_company_list[::-1]
# Out:
# Index(['Acer', 'HP', 'Lenovo', 'Asus', 'Dell', 'Toshiba', 'Apple', 'MSI'], dtype='object', name='Company')

# %%
sns.color_palette('Greens')
# Out:
# [(0.8828143021914648, 0.9546943483275664, 0.8621914648212226),
#  (0.7371472510572856, 0.895517108804306, 0.7108342945021145),
#  (0.5573241061130334, 0.8164244521337947, 0.546958861976163),
#  (0.3388235294117647, 0.7117262591311034, 0.40584390618992694),
#  (0.17139561707035755, 0.581514801999231, 0.2979008073817762),
#  (0.017762399077277974, 0.44267589388696654, 0.18523644752018453)]

# %%
sns.barplot(x=df['Company'],y=df['Price'],errorbar=None,order=sorted_company_list,
            hue=df['Company'],palette='Greens',hue_order=sorted_company_list[::-1])
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
df.sample()
# Out:
#     Company         Product  TypeName  Inches   ScreenResolution  \
# 632    Dell  Latitude E7470  Notebook    14.0  Full HD 1920x1080
#
#                             Cpu  Ram     Memory                    Gpu  \
# 632  Intel Core i5 6300U 2.4GHz  8GB  256GB SSD  Intel HD Graphics 520
#
#           OpSys  Weight   Price
# 632  Windows 10  1.56kg  127100

# %%
print(df['Product'].value_counts())
# Out:
# Product
# XPS 13                30
# Inspiron 3567         25
# 250 G6                21
# Vostro 3568           19
# Legion Y520-15IKBN    19
#                       ..
# Portege X30-D-10L      1
# Zenbook UX390UA        1
# Portege X30-D-10J      1
# Latitude E5470         1
# VivoBook E12           1
# Name: count, Length: 589, dtype: int64

# %%
df.drop(columns=['Product'],inplace=True)
# Out:
# /tmp/ipython-input-163803204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Product'],inplace=True)

# %%
print(df['TypeName'].value_counts())
# Out:
# TypeName
# Notebook              688
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
df.groupby('TypeName')['Price'].mean().sort_values(ascending=False)
# Out:
# TypeName
# Workstation           235875.862069
# Gaming                172919.000000
# Ultrabook             160354.970760
# 2 in 1 Convertible    134414.912281
# Notebook               82330.087209
# Netbook                71554.545455
# Name: Price, dtype: float64

# %%
sorted_typelist=df.groupby('TypeName')['Price'].mean().sort_values(ascending=False).index
sorted_typelist
# Out:
# Index(['Workstation', 'Gaming', 'Ultrabook', '2 in 1 Convertible', 'Notebook',
#        'Netbook'],
#       dtype='object', name='TypeName')

# %%
sns.barplot(x=df['TypeName'],y=df['Price'],errorbar=None,order=sorted_typelist,
            palette='Greens',hue=df['TypeName'],hue_order=sorted_typelist[::-1])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#     Company TypeName  Inches   ScreenResolution                          Cpu  \
# 197  Lenovo   Gaming    15.6  Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
#
#       Ram     Memory                      Gpu  OpSys Weight   Price
# 197  16GB  512GB SSD  Nvidia GeForce GTX 1060  No OS  2.4kg  144600

# %%
print(df['Inches'].value_counts())
# Out:
# Inches
# 15.6    637
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
sns.histplot(df['Inches'],kde=True)
# Out:
# <Axes: xlabel='Inches', ylabel='Count'>

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
print(df['ScreenResolution'].value_counts())
# Out:
# ScreenResolution
# Full HD 1920x1080                                492
# 1366x768                                         258
# IPS Panel Full HD 1920x1080                      217
# IPS Panel Full HD / Touchscreen 1920x1080         48
# Full HD / Touchscreen 1920x1080                   45
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     10
# 4K Ultra HD / Touchscreen 3840x2160                8
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Touchscreen 2560x1440                    5
# IPS Panel Quad HD+ / Touchscreen 3200x1800         4
# IPS Panel Touchscreen 1920x1200                    4
# IPS Panel Retina Display 2880x1800                 4
# 1440x900                                           4
# IPS Panel 2560x1440                                4
# Quad HD+ 3200x1800                                 3
# IPS Panel Quad HD+ 2560x1440                       3
# 2560x1440                                          3
# IPS Panel Touchscreen 1366x768                     3
# IPS Panel Touchscreen / 4K Ultra HD 3840x2160      2
# 1920x1080                                          2
# IPS Panel Quad HD+ 3200x1800                       2
# Touchscreen / Quad HD+ 3200x1800                   1
# IPS Panel Full HD 1366x768                         1
# IPS Panel Full HD 2560x1440                        1
# Touchscreen / Full HD 1920x1080                    1
# Name: count, dtype: int64

# %%
a="IPS Panel Full HD / Touchscreen 1920x1080"
a.split()[-1].split('x')[0]
# Out:
# '1920'

# %%
(lambda a:a.split()[-1].split('x')[0])("IPS Panel Full HD / Touchscreen 1920x1080")
# Out:
# '1920'

# %%
df['X_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
df['Y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if "Touchscreen" in a else 0)
df['IPS']=df['ScreenResolution'].apply(lambda a:1 if "IPS" in a else 0)
# Out:
# /tmp/ipython-input-2189414455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['X_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
# /tmp/ipython-input-2189414455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Y_res']=df['ScreenResolution'].apply(lambda a:a.split()[-1].split('x')[0]).astype('int')
# /tmp/ipython-input-2189414455.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Touchscreen']=df['ScreenResolution'].apply(lambda a:1 if "Touchscreen" in a else 0)
# /tmp/ipython-input-2189414455.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IPS']=df['ScreenResolution'].apply(lambda a:1 if "IPS" in a else 0)

# %%
a="IPS Panel Full HD / Touchscreen 1920x1080"
[1 if "Touchscreen" in a else 0]
# Out:
# [1]

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches                     ScreenResolution  \
# 1090      HP  Ultrabook    15.6                    Full HD 1920x1080
# 880     Dell   Notebook    15.6                             1366x768
# 691   Lenovo  Ultrabook    14.0          IPS Panel Full HD 1920x1080
# 612     Dell   Notebook    15.6  4K Ultra HD / Touchscreen 3840x2160
# 31        HP   Notebook    17.3                    Full HD 1920x1080
#
#                               Cpu   Ram     Memory                      Gpu  \
# 1090   Intel Core i7 6500U 2.5GHz   8GB  256GB SSD    Intel HD Graphics 520
# 880    Intel Core i5 6200U 2.3GHz   4GB  500GB HDD    Intel HD Graphics 520
# 691    Intel Core i5 7200U 2.5GHz   8GB  256GB SSD    Intel HD Graphics 620
# 612   Intel Core i7 7700HQ 2.8GHz  16GB    1TB SSD  Nvidia GeForce GTX 1050
# 31      AMD A6-Series 9220 2.5GHz   4GB  500GB HDD           AMD Radeon 530
#
#            OpSys  Weight   Price  X_res  Y_res  Touchscreen  IPS
# 1090   Windows 7  1.88kg  224600   1920   1920            0    0
# 880   Windows 10  1.95kg   75500   1366   1366            0    0
# 691   Windows 10  1.32kg  155100   1920   1920            0    1
# 612   Windows 10  2.06kg  248200   3840   3840            1    0
# 31    Windows 10  2.71kg   45400   1920   1920            0    0

# %%
df.drop(columns=['ScreenResolution'],inplace=True)
# Out:
# /tmp/ipython-input-840532398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.sample()
# Out:
#     Company     TypeName  Inches                          Cpu  Ram   Memory  \
# 905      HP  Workstation    15.6  Intel Core i7 6820HQ 2.7GHz  8GB  8GB SSD
#
#                       Gpu       OpSys Weight   Price  X_res  Y_res  \
# 905  Nvidia Quadro M1000M  Windows 10  2.0kg  232600   1920   1920
#
#      Touchscreen  IPS
# 905            0    1

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
sns.barplot(x=df['IPS'],y=df['Price'],errorbar=None)
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %%
print(df['Cpu'].value_counts())
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz              183
# Intel Core i7 7700HQ 2.8GHz             142
# Intel Core i7 7500U 2.7GHz              124
# Intel Core i5 8250U 1.6GHz               71
# Intel Core i7 8550U 1.8GHz               71
#                                        ...
# Intel Pentium Dual Core 4405Y 1.5GHz      1
# Intel Core M 6Y54 1.1GHz                  1
# AMD E-Series 9000 2.2GHz                  1
# Intel Core M 6Y30 0.9GHz                  1
# AMD A9-Series 9410 2.9GHz                 1
# Name: count, Length: 111, dtype: int64

# %%
df['Cpu_Speed']=df['Cpu'].apply(lambda x:x.split()[-1].replace('GHz',"")).astype('float')
# Out:
# /tmp/ipython-input-472277883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu_Speed']=df['Cpu'].apply(lambda x:x.split()[-1].replace('GHz',"")).astype('float')

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 74    Lenovo            Notebook    15.6
# 806       HP  2 in 1 Convertible    11.6
# 1184      HP            Notebook    15.6
# 81    Lenovo            Notebook    15.6
# 209     Dell           Ultrabook    14.0
#
#                                        Cpu  Ram              Memory  \
# 74              Intel Core i5 7200U 2.5GHz  8GB             2TB HDD
# 806   Intel Celeron Dual Core N3350 1.1GHz  4GB  32GB Flash Storage
# 1184              Intel Core i3 6006U 2GHz  4GB             1TB HDD
# 81               AMD A6-Series 9220 2.5GHz  4GB           128GB SSD
# 209             Intel Core i5 8250U 1.6GHz  8GB           256GB SSD
#
#                          Gpu       OpSys Weight   Price  X_res  Y_res  \
# 74     Intel HD Graphics 620       No OS  2.2kg   53700   1920   1920
# 806    Intel HD Graphics 500   Chrome OS  1.4kg   63600   1366   1366
# 1184   Intel HD Graphics 520  Windows 10  2.1kg   49400   1920   1920
# 81           AMD R4 Graphics  Windows 10  2.2kg   41300   1920   1920
# 209   Intel UHD Graphics 620  Windows 10  1.6kg  118900   1920   1920
#
#       Touchscreen  IPS  Cpu_Speed
# 74              0    0        2.5
# 806             1    0        1.1
# 1184            0    0        2.0
# 81              0    0        2.5
# 209             0    0        1.6

# %%
df['Cpu']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
# Out:
# /tmp/ipython-input-322039739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
print(df['Cpu'].value_counts())
# Out:
# Cpu
# Intel Core i7               493
# Intel Core i5               411
# Intel Core i3               134
# Intel Celeron Dual           66
# Intel Pentium Quad           27
# Intel Core M                 16
# AMD A9-Series 9420           12
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# Intel Atom x5-Z8550           4
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A6-Series A6-9220         2
# AMD A9-Series A9-9420         2
# AMD A10-Series 9600P          2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# Intel Xeon E3-1535M           2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD E-Series 9000e            1
# AMD E-Series E2-6110          1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# Intel Atom x5-Z8350           1
# AMD Ryzen 1600                1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# AMD A12-Series 9700P          1
# AMD A4-Series 7210            1
# AMD FX 8800P                  1
# AMD E-Series 9000             1
# AMD A9-Series 9410            1
# Name: count, dtype: int64

# %%
def fetch_processor_name(proc):
    if proc.split()[0]=='Intel':
        if proc.split()[1]=='Core':
            return proc
        else:
            return " ".join(proc.split()[0:2])
    else:
        if proc[4]=="E":
            return "AMD E-Series"
        elif proc[4]=="R":
            return "AMD Ryzen Series"
        elif proc[4]=="A":
            return "AMD A Series"
        else:
            return "AMD FX Series"

# %%
df['Cpu']=df['Cpu'].apply(fetch_processor_name)
# Out:
# /tmp/ipython-input-4081625852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cpu']=df['Cpu'].apply(fetch_processor_name)

# %%
print(df['Cpu'].value_counts())
# Out:
# Cpu
# Intel Core i7       493
# Intel Core i5       411
# Intel Core i3       134
# Intel Celeron        71
# AMD A Series         45
# Intel Pentium        30
# Intel Core M         16
# AMD E-Series          9
# Intel Atom            5
# AMD Ryzen Series      4
# Intel Xeon            4
# AMD FX Series         2
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
sorted_cpulist=df.groupby('Cpu')['Price'].mean().sort_values(ascending=False).index
sorted_cpulist
# Out:
# Index(['Intel Xeon', 'AMD Ryzen Series', 'Intel Core i7', 'Intel Core M',
#        'Intel Core i5', 'AMD FX Series', 'Intel Core i3', 'AMD A Series',
#        'Intel Atom', 'Intel Pentium', 'Intel Celeron', 'AMD E-Series'],
#       dtype='object', name='Cpu')

# %%
sns.barplot(x=df['Cpu'],y=df['Price'],errorbar=None,order=sorted_cpulist,
            palette='Greens',hue=df['Cpu'],hue_order=sorted_cpulist[::-1])
plt.xticks(rotation=90)
plt.show()

# %%
df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype('int')
df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')
# Out:
# /tmp/ipython-input-697797018.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ram']=df['Ram'].apply(lambda x:x.replace("GB","")).astype('int')
# /tmp/ipython-input-697797018.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight']=df['Weight'].apply(lambda x:x.replace("kg","")).astype('float')

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
sns.barplot(x=df['Ram'],y=df['Price'],errorbar=None,hue=df['Ram'])
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
print(df['Gpu'].value_counts())
# Out:
# Gpu
# Intel HD Graphics 620      265
# Intel HD Graphics 520      179
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     65
# Nvidia GeForce GTX 1060     45
#                           ...
# AMD Radeon R5 M315           1
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# Name: count, Length: 108, dtype: int64

# %%
df['Gpu']=df['Gpu'].apply(lambda x:" ".join(x.split()[0:2]))
# Out:
# /tmp/ipython-input-128801801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gpu']=df['Gpu'].apply(lambda x:" ".join(x.split()[0:2]))

# %%
print(df['Gpu'].value_counts())
# Out:
# Gpu
# Intel HD          586
# Nvidia GeForce    353
# AMD Radeon        166
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# AMD FirePro         5
# Nvidia GTX          1
# AMD R4              1
# AMD R17M-M1-70      1
# Intel Graphics      1
# Name: count, dtype: int64

# %%
def fetch_gpu_name(text):
    if text.split()[0]=='AMD':
        return "AMD GPU"
    elif text=="Intel Graphics":
        return "Intel HD"
    elif text=="Nvidia GTX":
        return "Nvidia GeForce"
    else:
        return text

# %%
df['Gpu']=df['Gpu'].apply(fetch_gpu_name)
# Out:
# /tmp/ipython-input-1998461726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gpu']=df['Gpu'].apply(fetch_gpu_name)

# %%
print(df['Gpu'].value_counts())
# Out:
# Gpu
# Intel HD          587
# Nvidia GeForce    354
# AMD GPU           173
# Intel UHD          68
# Nvidia Quadro      31
# Intel Iris         11
# Name: count, dtype: int64

# %%
df['Gpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gpu'>

# %%
df.groupby('Gpu')['Price'].mean()
# Out:
# Gpu
# AMD GPU            79874.566474
# Intel HD          101831.516184
# Intel Iris        178827.272727
# Intel UHD         124722.058824
# Nvidia GeForce    142543.502825
# Nvidia Quadro     254306.451613
# Name: Price, dtype: float64

# %%
sorted_gpulist=df.groupby('Gpu')['Price'].mean().sort_values(ascending=False).index
sorted_gpulist
# Out:
# Index(['Nvidia Quadro', 'Intel Iris', 'Nvidia GeForce', 'Intel UHD',
#        'Intel HD', 'AMD GPU'],
#       dtype='object', name='Gpu')

# %%
sns.barplot(x=df['Gpu'],y=df['Price'],errorbar=None,order=sorted_gpulist,
            palette='Greens',hue=df['Gpu'],hue_order=sorted_gpulist[::-1])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram     Memory       Gpu  \
# 743    Asus  Notebook    15.6  Intel Pentium    8  128GB SSD  Intel HD
#
#           OpSys  Weight  Price  X_res  Y_res  Touchscreen  IPS  Cpu_Speed
# 743  Windows 10     2.0  60200   1920   1920            0    0        1.1

# %%
print(df['OpSys'].value_counts())
# Out:
# OpSys
# Windows 10      1011
# No OS             63
# Linux             58
# Windows 7         45
# Chrome OS         22
# macOS             13
# Mac OS X           8
# Windows 10 S       2
# Android            2
# Name: count, dtype: int64

# %%
def fetch_os_name(os):
    if os=="Windows 10 S":
        return "Windows 10"
    elif os=="macOS" or os=="Mac OS X":
        return "MacOS"
    elif os=="Android" or os=="Chrome OS" or os=="Linux":
        return "Linux/Chrome OS/Others"
    else:
        return os

# %%
df['OpSys']=df['OpSys'].apply(fetch_os_name)
# Out:
# /tmp/ipython-input-1810890622.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OpSys']=df['OpSys'].apply(fetch_os_name)

# %%
print(df['OpSys'].value_counts())
# Out:
# OpSys
# Windows 10                1013
# Linux/Chrome OS/Others      82
# No OS                       63
# Windows 7                   45
# MacOS                       21
# Name: count, dtype: int64

# %%
sorted_oslist=df.groupby('OpSys')['Price'].mean().sort_values(ascending=False).index
sorted_oslist
# Out:
# Index(['Windows 7', 'MacOS', 'Windows 10', 'Linux/Chrome OS/Others', 'No OS'], dtype='object', name='OpSys')

# %%
sns.barplot(x=df['OpSys'],y=df['Price'],errorbar=None,order=sorted_oslist,
            palette='Greens',hue=df['OpSys'],hue_order=sorted_oslist[::-1])
plt.xticks(rotation=90)
plt.show()

# %%
print(df['Memory'].value_counts())
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          214
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 256GB SSD +  2TB HDD              10
# 64GB Flash Storage                10
# 256GB Flash Storage                8
# 1.0TB Hybrid                       7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 32GB SSD                           2
# 256GB SSD +  256GB SSD             2
# 1TB SSD +  1TB HDD                 2
# 512GB Flash Storage                2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 512GB SSD +  512GB SSD             1
# 64GB SSD                           1
# 64GB Flash Storage +  1TB HDD      1
# 512GB SSD +  256GB SSD             1
# 1TB HDD +  1TB HDD                 1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 1.0TB HDD                          1
# 512GB SSD +  1.0TB Hybrid          1
# 256GB SSD +  1.0TB Hybrid          1
# Name: count, dtype: int64

# %%
# SSD
# HDD
# SSD+HDD
# Flash Storage
# Hybrid
# SSD + SSD
# Flash Storage+SSD
# HDD + HDD
# SSD + Hybrid

# SSD  HDD   Flash Storage     Hybrid

# %%
df['Memory']=df['Memory'].astype(str).replace(r"\.0","",regex=True)
# Out:
# /tmp/ipython-input-3954205664.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory']=df['Memory'].astype(str).replace(r"\.0","",regex=True)

# %%
# 1TB=1000GB

# %%
print(df['Memory'].value_counts())
# Out:
# Memory
# 256GB SSD                        393
# 1TB HDD                          215
# 500GB HDD                        124
# 512GB SSD                        105
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                29
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           12
# 64GB Flash Storage                10
# 256GB SSD +  2TB HDD              10
# 256GB Flash Storage                8
# 1TB Hybrid                         7
# 16GB Flash Storage                 6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 128GB SSD +  2TB HDD               2
# 32GB SSD                           2
# 256GB SSD +  500GB HDD             2
# 1TB SSD +  1TB HDD                 2
# 64GB SSD                           1
# 512GB SSD +  256GB SSD             1
# 512GB SSD +  512GB SSD             1
# 1TB HDD +  1TB HDD                 1
# 64GB Flash Storage +  1TB HDD      1
# 128GB HDD                          1
# 240GB SSD                          1
# 8GB SSD                            1
# 508GB Hybrid                       1
# 512GB SSD +  1TB Hybrid            1
# 256GB SSD +  1TB Hybrid            1
# Name: count, dtype: int64

# %%
df['Memory']=df['Memory'].str.replace("GB","")
df['Memory']=df['Memory'].str.replace("TB","000")
# Out:
# /tmp/ipython-input-3547922039.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory']=df['Memory'].str.replace("GB","")
# /tmp/ipython-input-3547922039.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Memory']=df['Memory'].str.replace("TB","000")

# %%
print(df['Memory'].value_counts())
# Out:
# Memory
# 256 SSD                         393
# 1000 HDD                        215
# 500 HDD                         124
# 512 SSD                         105
# 128 SSD +  1000 HDD              93
# 256 SSD +  1000 HDD              73
# 128 SSD                          71
# 32 Flash Storage                 29
# 2000 HDD                         16
# 512 SSD +  1000 HDD              14
# 1000 SSD                         12
# 64 Flash Storage                 10
# 256 SSD +  2000 HDD              10
# 256 Flash Storage                 8
# 1000 Hybrid                       7
# 16 Flash Storage                  6
# 180 SSD                           5
# 128 Flash Storage                 4
# 512 SSD +  2000 HDD               3
# 16 SSD                            3
# 256 SSD +  256 SSD                2
# 512 Flash Storage                 2
# 128 SSD +  2000 HDD               2
# 32 SSD                            2
# 256 SSD +  500 HDD                2
# 1000 SSD +  1000 HDD              2
# 64 SSD                            1
# 512 SSD +  256 SSD                1
# 512 SSD +  512 SSD                1
# 1000 HDD +  1000 HDD              1
# 64 Flash Storage +  1000 HDD      1
# 128 HDD                           1
# 240 SSD                           1
# 8 SSD                             1
# 508 Hybrid                        1
# 512 SSD +  1000 Hybrid            1
# 256 SSD +  1000 Hybrid            1
# Name: count, dtype: int64

# %%
new=df['Memory'].str.split('+',expand=True)
df['first']=new[0]
df['first']=df['first'].str.strip()
df['second']=new[1]
# Out:
# /tmp/ipython-input-1513280885.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first']=new[0]
# /tmp/ipython-input-1513280885.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first']=df['first'].str.strip()
# /tmp/ipython-input-1513280885.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second']=new[1]

# %%
df.sample(3)
# Out:
#     Company            TypeName  Inches            Cpu  Ram    Memory  \
# 225    Acer  2 in 1 Convertible    13.3  Intel Core i5    8   256 SSD
# 460  Lenovo            Notebook    14.0  Intel Core i5    8   180 SSD
# 818    Dell            Notebook    13.3  Intel Core i5    8  1000 HDD
#
#           Gpu       OpSys  Weight   Price  X_res  Y_res  Touchscreen  IPS  \
# 225  Intel HD  Windows 10    1.60   71300   1920   1920            1    1
# 460  Intel HD  Windows 10    1.70  141100   1920   1920            0    0
# 818  Intel HD  Windows 10    1.62   67100   1920   1920            1    0
#
#      Cpu_Speed     first second
# 225        2.3   256 SSD   None
# 460        2.5   180 SSD   None
# 818        2.3  1000 HDD   None

# %%
df['Layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer1Hybrid']=df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer1Flash_Storage']=df['first'].apply(lambda x:1 if "Flash" in x else 0)
# Out:
# /tmp/ipython-input-3905744447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0)
# /tmp/ipython-input-3905744447.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
# /tmp/ipython-input-3905744447.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer1Hybrid']=df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
# /tmp/ipython-input-3905744447.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer1Flash_Storage']=df['first'].apply(lambda x:1 if "Flash" in x else 0)

# %%
df.sample(3)
# Out:
#      Company  TypeName  Inches            Cpu  Ram               Memory  \
# 228     Asus  Notebook    15.6   AMD A Series    4  128 SSD +  1000 HDD
# 1071    Asus    Gaming    17.3  Intel Core i7    8  128 SSD +  1000 HDD
# 495     Dell  Notebook    15.6  Intel Core i7   16  256 SSD +  2000 HDD
#
#                  Gpu       OpSys  Weight   Price  ...  Y_res  Touchscreen  \
# 228          AMD GPU  Windows 10    2.20   59500  ...   1920            0
# 1071  Nvidia GeForce  Windows 10    3.52  135800  ...   1920            0
# 495          AMD GPU  Windows 10    2.20  126100  ...   1920            0
#
#       IPS  Cpu_Speed    first      second Layer1HDD  Layer1SSD  Layer1Hybrid  \
# 228     0        2.5  128 SSD    1000 HDD         0          1             0
# 1071    0        2.6  128 SSD    1000 HDD         0          1             0
# 495     0        1.8  256 SSD    2000 HDD         0          1             0
#
#       Layer1Flash_Storage
# 228                     0
# 1071                    0
# 495                     0
#
# [3 rows x 21 columns]

# %%
df['first']=df['first'].str.replace(r"\D","",regex=True)
# \D: any character which is not a digit
# \d: any character which is a digit
# Out:
# /tmp/ipython-input-665997184.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first']=df['first'].str.replace(r"\D","",regex=True)

# %%
df.sample(3)
# Out:
#     Company   TypeName  Inches            Cpu  Ram   Memory             Gpu  \
# 209    Dell  Ultrabook    14.0  Intel Core i5    8  256 SSD       Intel UHD
# 771    Dell     Gaming    15.6  Intel Core i7   16  512 SSD  Nvidia GeForce
# 364  Lenovo   Notebook    17.3   AMD A Series    4  128 SSD         AMD GPU
#
#           OpSys  Weight   Price  ...  Y_res  Touchscreen  IPS  Cpu_Speed  \
# 209  Windows 10    1.60  118900  ...   1920            0    0        1.6
# 771  Windows 10    2.62  173700  ...   3840            0    0        2.8
# 364  Windows 10    2.60   50600  ...   1600            0    0        2.2
#
#      first second Layer1HDD  Layer1SSD  Layer1Hybrid  Layer1Flash_Storage
# 209    256   None         0          1             0                    0
# 771    512   None         0          1             0                    0
# 364    128   None         0          1             0                    0
#
# [3 rows x 21 columns]

# %%
df['second'].fillna("0",inplace=True)
df['second']=df['second'].str.strip()
df['Layer2HDD']=df['second'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer2Hybrid']=df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer2Flash_Storage']=df['second'].apply(lambda x:1 if "Flash" in x else 0)
df['second']=df['second'].str.replace(r"\D","",regex=True)
# Out:
# /tmp/ipython-input-767682752.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['second'].fillna("0",inplace=True)
# /tmp/ipython-input-767682752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second'].fillna("0",inplace=True)
# /tmp/ipython-input-767682752.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second']=df['second'].str.strip()
# /tmp/ipython-input-767682752.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer2HDD']=df['second'].apply(lambda x:1 if "HDD" in x else 0)
# /tmp/ipython-input-767682752.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
# /tmp/ipython-input-767682752.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer2Hybrid']=df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
# /tmp/ipython-input-767682752.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Layer2Flash_Storage']=df['second'].apply(lambda x:1 if "Flash" in x else 0)
# /tmp/ipython-input-767682752.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second']=df['second'].str.replace(r"\D","",regex=True)

# %%
df.sample()
# Out:
#     Company  TypeName  Inches            Cpu  Ram    Memory             Gpu  \
# 775    Dell  Notebook    15.6  Intel Core i7    8  1000 HDD  Nvidia GeForce
#
#           OpSys  Weight  Price  ...  first  second  Layer1HDD  Layer1SSD  \
# 775  Windows 10    1.98  99400  ...   1000       0          1          0
#
#      Layer1Hybrid Layer1Flash_Storage Layer2HDD  Layer2SSD  Layer2Hybrid  \
# 775             0                   0         0          0             0
#
#      Layer2Flash_Storage
# 775                    0
#
# [1 rows x 25 columns]

# %%
df['first']=df['first'].astype('int')
df['second']=df['second'].astype('int')
# Out:
# /tmp/ipython-input-230615495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['first']=df['first'].astype('int')
# /tmp/ipython-input-230615495.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['second']=df['second'].astype('int')

# %%
df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
df['Flash_Storage']=df['first']*df['Layer1Flash_Storage']+df['second']*df['Layer2Flash_Storage']
# Out:
# /tmp/ipython-input-3956490038.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
# /tmp/ipython-input-3956490038.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
# /tmp/ipython-input-3956490038.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
# /tmp/ipython-input-3956490038.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Flash_Storage']=df['first']*df['Layer1Flash_Storage']+df['second']*df['Layer2Flash_Storage']

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys',
#        'Weight', 'Price', 'X_res', 'Y_res', 'Touchscreen', 'IPS', 'Cpu_Speed',
#        'first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
#        'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
#        'Layer2Flash_Storage', 'HDD', 'SSD', 'Hybrid', 'Flash_Storage'],
#       dtype='object')

# %%
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# /tmp/ipython-input-1625865374.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',

# %%
df.sample(10)
# Out:
#      Company   TypeName  Inches            Cpu  Ram               Memory  \
# 425   Lenovo  Ultrabook    14.0  Intel Core i7   24              512 SSD
# 25      Dell   Notebook    15.6  Intel Core i3    4             1000 HDD
# 593      MSI     Gaming    15.6  Intel Core i7   16  256 SSD +  1000 HDD
# 428     Dell   Notebook    15.6  Intel Core i5    4              256 SSD
# 617     Acer   Notebook    15.6  Intel Core i3    4              500 HDD
# 757    Apple  Ultrabook    12.0   Intel Core M    8    512 Flash Storage
# 627  Toshiba   Notebook    15.6  Intel Core i5    8              500 HDD
# 323     Asus   Notebook    14.0  Intel Core i7    8  256 SSD +  1000 HDD
# 511     Dell     Gaming    17.3  Intel Core i7   16  128 SSD +  1000 HDD
# 897     Acer   Notebook    15.6  Intel Core i5    4              500 HDD
#
#                 Gpu       OpSys  Weight   Price  X_res  Y_res  Touchscreen  \
# 425        Intel HD  Windows 10    1.32  246400   2560   2560            0
# 25         Intel HD  Windows 10    2.30   43300   1366   1366            0
# 593  Nvidia GeForce  Windows 10    2.94  234600   1920   1920            0
# 428         AMD GPU  Windows 10    2.20   77500   1920   1920            0
# 617        Intel HD  Windows 10    2.40   46500   1366   1366            0
# 757        Intel HD       MacOS    0.92  120500   2304   2304            0
# 627        Intel HD  Windows 10    2.00  110100   1920   1920            0
# 323        Intel HD  Windows 10    2.00  138000   1920   1920            0
# 511  Nvidia GeForce  Windows 10    4.42  311600   1920   1920            0
# 897        Intel HD  Windows 10    2.23   64000   1366   1366            0
#
#      IPS  Cpu_Speed   HDD  SSD  Hybrid  Flash_Storage
# 425    0        2.7     0  512       0              0
# 25     0        2.0  1000    0       0              0
# 593    0        2.8  1000  256       0              0
# 428    0        1.6     0  256       0              0
# 617    0        2.0   500    0       0              0
# 757    1        1.2     0    0       0            512
# 627    1        2.5   500    0       0              0
# 323    0        2.7  1000  256       0              0
# 511    1        2.8  1000  128       0              0
# 897    0        2.5   500    0       0              0

# %%
df.drop(columns=['Memory'],inplace=True)
# Out:
# /tmp/ipython-input-223790573.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Memory'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1224 non-null   object
#  1   TypeName       1224 non-null   object
#  2   Inches         1224 non-null   float64
#  3   Cpu            1224 non-null   object
#  4   Ram            1224 non-null   int64
#  5   Gpu            1224 non-null   object
#  6   OpSys          1224 non-null   object
#  7   Weight         1224 non-null   float64
#  8   Price          1224 non-null   int64
#  9   X_res          1224 non-null   int64
#  10  Y_res          1224 non-null   int64
#  11  Touchscreen    1224 non-null   int64
#  12  IPS            1224 non-null   int64
#  13  Cpu_Speed      1224 non-null   float64
#  14  HDD            1224 non-null   int64
#  15  SSD            1224 non-null   int64
#  16  Hybrid         1224 non-null   int64
#  17  Flash_Storage  1224 non-null   int64
# dtypes: float64(3), int64(10), object(5)
# memory usage: 172.3+ KB

# %%
df.corr(numeric_only=True)
# Out:
#                  Inches       Ram    Weight     Price     X_res     Y_res  \
# Inches         1.000000  0.239155  0.824959  0.055335 -0.057739 -0.057739
# Ram            0.239155  1.000000  0.394187  0.726652  0.415731  0.415731
# Weight         0.824959  0.394187  1.000000  0.212050 -0.025155 -0.025155
# Price          0.055335  0.726652  0.212050  1.000000  0.553715  0.553715
# X_res         -0.057739  0.415731 -0.025155  0.553715  1.000000  1.000000
# Y_res         -0.057739  0.415731 -0.025155  0.553715  1.000000  1.000000
# Touchscreen   -0.359497  0.094037 -0.291506  0.161428  0.320954  0.320954
# IPS           -0.104090  0.223322  0.038753  0.289236  0.283969  0.283969
# Cpu_Speed      0.296510  0.356482  0.313267  0.422566  0.187056  0.187056
# HDD            0.525077  0.106175  0.503765 -0.093761 -0.109044 -0.109044
# SSD           -0.114322  0.589636 -0.063144  0.654757  0.523882  0.523882
# Hybrid         0.050989  0.052774  0.105129  0.025531 -0.000097 -0.000097
# Flash_Storage -0.230659 -0.047725 -0.178962 -0.023375 -0.013602 -0.013602
#
#                Touchscreen       IPS  Cpu_Speed       HDD       SSD    Hybrid  \
# Inches           -0.359497 -0.104090   0.296510  0.525077 -0.114322  0.050989
# Ram               0.094037  0.223322   0.356482  0.106175  0.589636  0.052774
# Weight           -0.291506  0.038753   0.313267  0.503765 -0.063144  0.105129
# Price             0.161428  0.289236   0.422566 -0.093761  0.654757  0.025531
# X_res             0.320954  0.283969   0.187056 -0.109044  0.523882 -0.000097
# Y_res             0.320954  0.283969   0.187056 -0.109044  0.523882 -0.000097
# Touchscreen       1.000000  0.154500  -0.105203 -0.195492  0.240469 -0.035892
# IPS               0.154500  1.000000   0.085098 -0.087397  0.228186 -0.013349
# Cpu_Speed        -0.105203  0.085098   1.000000  0.115310  0.248993  0.049271
# HDD              -0.195492 -0.087397   0.115310  1.000000 -0.407685 -0.073848
# SSD               0.240469  0.228186   0.248993 -0.407685  1.000000 -0.050250
# Hybrid           -0.035892 -0.013349   0.049271 -0.073848 -0.050250  1.000000
# Flash_Storage    -0.012073  0.074771  -0.214263 -0.112475 -0.140474 -0.012602
#
#                Flash_Storage
# Inches             -0.230659
# Ram                -0.047725
# Weight             -0.178962
# Price              -0.023375
# X_res              -0.013602
# Y_res              -0.013602
# Touchscreen        -0.012073
# IPS                 0.074771
# Cpu_Speed          -0.214263
# HDD                -0.112475
# SSD                -0.140474
# Hybrid             -0.012602
# Flash_Storage       1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),cmap='summer')
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches           0.055335
# Ram              0.726652
# Weight           0.212050
# Price            1.000000
# X_res            0.553715
# Y_res            0.553715
# Touchscreen      0.161428
# IPS              0.289236
# Cpu_Speed        0.422566
# HDD             -0.093761
# SSD              0.654757
# Hybrid           0.025531
# Flash_Storage   -0.023375
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)
# Out:
# /tmp/ipython-input-44803004.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
# screen size       : Inches
# screen resolution : X_res, Y_res
# resolution: number of pixels on the screen
# pixel density

# %%
df['ppi']=round((df['X_res']**2+df['Y_res']**2)**0.5/df['Inches'],2)
# Out:
# /tmp/ipython-input-3589109359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ppi']=round((df['X_res']**2+df['Y_res']**2)**0.5/df['Inches'],2)

# %%
df.corr(numeric_only=True)['Price']
# Out:
# Inches         0.055335
# Ram            0.726652
# Weight         0.212050
# Price          1.000000
# X_res          0.553715
# Y_res          0.553715
# Touchscreen    0.161428
# IPS            0.289236
# Cpu_Speed      0.422566
# HDD           -0.093761
# SSD            0.654757
# ppi            0.484530
# Name: Price, dtype: float64

# %%
df.drop(columns=['X_res','Y_res','Inches'],inplace=True)
# Out:
# /tmp/ipython-input-3514242893.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['X_res','Y_res','Inches'],inplace=True)

# %%
# screen size       : Inches
# screen resolution : X_res, Y_res
# resolution: number of pixels on the screen
# pixel density

# %%
# screen size       : Inches
# screen resolution : X_res, Y_res
# resolution: number of pixels on the screen
# pixel density

# %%
X=df.drop(columns=['Price'])
y=df['Price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.15,random_state=42)

# %%
X.shape,X_train.shape,X_test.shape
# Out:
# ((1224, 13), (1040, 13), (184, 13))

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingRegressor, AdaBoostRegressor
from xgboost import XGBRegressor

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
from sklearn.metrics import r2_score, mean_absolute_error, root_mean_squared_error

# %%
# Encoding : process of converting text data to numerical data
# Label Encoding (output labels)
    # LabelEncoder
# Feature Encoding (input features)
    # Ordinal Encoding  : Very Good(2), Poor(0), Excellent(3), Satisfactory(1)
        # OrdinalEncoder
    # Nominal Encoding  : Man/Woman , Apple/Acer/Dell/HP
        # OneHotEncoder

# %%
# Company     Company_HP  Company_Ap
# Apple            0           1
# Apple            0           1
# HP               1           0
# Apple            0           1
# Dell             0           0
# HP               1           0
# Dell             0           0
# Apple            0           1

# %%
# Linear Regression
step1 = OneHotEncoder()
step2 = LinearRegression()
# step1+step2=pipeline

# pipe.fit(X_train,y_train)
# y_pred=pipe.predict(X_test)
# r2_score(y_test,y_pred)

# %%
X_train.sample()
# Out:
#     Company  TypeName            Cpu  Ram             Gpu       OpSys  Weight  \
# 116    Asus  Notebook  Intel Core i7    8  Nvidia GeForce  Windows 10     1.7
#
#      Touchscreen  IPS  Cpu_Speed  HDD  SSD     ppi
# 116            0    0        1.8    0  256  174.06

# %%
# Linear Regression
ct_ohe= ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
reg_model= LinearRegression()
pipe=Pipeline([('s1',ct_ohe),('s2',reg_model)])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("RMSE:",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7780057808788896
# MAE: 23053.0298556642
# RMSE: 32619.153231530505

# %%
# 1a - 1b
# 1b - 1c
# pipeline(1a)
# 1c

# %%
# Regularization Teechniques
# -Lasso()
# -Ridge()

# %%
X_train.sample()
# Out:
#     Company  TypeName            Cpu  Ram             Gpu       OpSys  Weight  \
# 608    Asus  Notebook  Intel Core i5    8  Nvidia GeForce  Windows 10    1.99
#
#      Touchscreen  IPS  Cpu_Speed   HDD  SSD     ppi
# 608            0    0        2.5  1000    0  174.06

# %%
# y=mx+c
# y=m1x1+m2x2+m3x3+... +c
# price=b1.RAM +b2.weight+b3.cpu+b4.cpu_speed+.....+b0

# %%
# Multi-collinearity
# Overfitting

# %%
# Ridge Regression : L2 Regularization : penalty: square of coefficients
ct_ohe= ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
reg_model= Ridge(alpha=1)
pipe=Pipeline([('s1',ct_ohe),('s2',reg_model)])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("RMSE:",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7809087156544672
# MAE: 23111.31167963917
# RMSE: 32405.177219293604

# %%
# Lasso Regression : L1 regularization : penalty : absolute value of coefficients
# internal automatic feature selection

# When is Lasso useful?
  # - When you have many features, and you think not all are useful
  # - you suspect some features are not important
  # - you want a simpler model


# Lasso is very sensitive to feature scaling
# if your features are on very different scales, it is a good idea to normalize or standardize them
# we will standardize numeric features using standardscaler.

# %%
# Lasso Regression
categorical_features=[0,1,2,4,5]
numerical_features=[3,6,7,8,9,10,11,12]
preprocessor= ColumnTransformer(transformers=[
    ('cat',OneHotEncoder(drop='first'),categorical_features),
    ('num',StandardScaler(),numerical_features)
    ])
reg_model= Lasso(alpha=0.01)
pipe=Pipeline([('s1',preprocessor),('s2',reg_model)])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("RMSE:",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7780048052204632
# MAE: 23053.110999233955
# RMSE: 32619.224911587913
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.517e+10, tolerance: 4.988e+08
#   model = cd_fast.enet_coordinate_descent(

# %%
X_train.sample()
# Out:
#     Company TypeName            Cpu  Ram             Gpu       OpSys  Weight  \
# 336  Lenovo   Gaming  Intel Core i7   16  Nvidia GeForce  Windows 10     2.4
#
#      Touchscreen  IPS  Cpu_Speed   HDD  SSD     ppi
# 336            0    1        2.8  2000  256  174.06

# %%
# Decision Tree Regression
ct_ohe= ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
reg_model= DecisionTreeRegressor(max_depth=11)
pipe=Pipeline([('s1',ct_ohe),('s2',reg_model)])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("RMSE:",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.7362483282484231
# MAE: 23825.105664084702
# RMSE: 35554.899940061885

# %%
# KNN(KNeighbours Classifier)

# %%
ct_ohe= ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
reg_model= KNeighborsClassifier(n_neighbors=3)
pipe=Pipeline([('s1',ct_ohe),('s2',reg_model)])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("RMSE:",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.4233936088153052
# MAE: 32851.63043478261
# RMSE: 52570.43566988711

# %%
# SVR(Support Vector Regressor)
categorical_features=[0,1,2,4,5]
numerical_features=[3,6,7,8,9,10,11,12]
preprocessor= ColumnTransformer(transformers=[
    ('cat',OneHotEncoder(drop='first'),categorical_features),
    ('num',StandardScaler(),numerical_features)
])
reg_model= SVR(C=100)
pipe=Pipeline([('s1',ct_ohe),('s2',reg_model)])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("RMSE:",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 score: -0.0331425320894172
# MAE: 48588.98478531605
# RMSE: 70369.0958031254

# %%
# Adaboost Regression
ct_ohe= ColumnTransformer(transformers=[('col_tnf',OneHotEncoder(drop='first'),[0,1,2,4,5])],remainder='passthrough')
reg_model= KNeighborsClassifier(n_neighbors=3)
pipe=Pipeline([('s1',ct_ohe),('s2',reg_model)])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("RMSE:",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.4233936088153052
# MAE: 32851.63043478261
# RMSE: 52570.43566988711

# %%
# Ensemble : combination of multiple algorithms
# Crowd always knows best answer

# %%
# Gradient Boosting
    # Gradient Descent

# %%
# XGB Regression
categorical_features=[0,1,2,4,5]
numerical_features=[3,6,7,8,9,10,11,12]
preprocessor= ColumnTransformer(transformers=[
    ('cat',OneHotEncoder(drop='first'),categorical_features),
    ('num',StandardScaler(),numerical_features)
    ])
reg_model= GradientBoostingRegressor(random_state=15,n_estimators=600, learning_rate=0.1,max_depth=2)
pipe=Pipeline([('s1',preprocessor),('s2',reg_model)])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("RMSE:",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8841911623671758
# MAE: 16906.922969077274
# RMSE: 23559.859792166422

# %%
# GradientBoosting Regression
categorical_features=[0,1,2,4,5]
numerical_features=[3,6,7,8,9,10,11,12]
preprocessor= ColumnTransformer(transformers=[
    ('cat',OneHotEncoder(drop='first'),categorical_features),
    ('num',StandardScaler(),numerical_features)
    ])
reg_model= GradientBoostingRegressor(random_state=15,n_estimators=950, learning_rate=0.1,max_depth=2)
pipe=Pipeline([('s1',preprocessor),('s2',reg_model)])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("RMSE:",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8889074147514046
# MAE: 16607.0117083716
# RMSE: 23075.142249077013

# %%
# Grid Search CV
from sklearn.model_selection import GridSearchCV

# %%
# GradientBoosting Regression
categorical_features=[0,1,2,4,5]
numerical_features=[3,6,7,8,9,10,11,12]
preprocessor= ColumnTransformer(transformers=[
    ('cat',OneHotEncoder(drop='first'),categorical_features),
    ('num',StandardScaler(),numerical_features)
    ])
reg_model= GradientBoostingRegressor(random_state=15,n_estimators=950, learning_rate=0.1,max_depth=2)
pipe=Pipeline([('s1',preprocessor),('s2',reg_model)])

pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
print("R2 score:",r2_score(y_test,y_pred))
print("MAE:",mean_absolute_error(y_test,y_pred))
print("RMSE:",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 score: 0.8889074147514046
# MAE: 16607.0117083716
# RMSE: 23075.142249077013

# %%
X.sample()
# Out:
#     Company  TypeName            Cpu  Ram       Gpu                   OpSys  \
# 281    Acer  Notebook  Intel Celeron    2  Intel HD  Linux/Chrome OS/Others
#
#      Weight  Touchscreen  IPS  Cpu_Speed  HDD  SSD     ppi
# 281    2.19            0    0        1.5    0   16  123.83

# %%
query=[['Dell','Notebook','Intel Core i5',18,'Intel HD','Windows 10',1.9,0,0,2.5,0,256,174.06]]

# %%
op=pipe.predict(query)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
op
# Out:
# array([124645.36993022])

# %%
print("The estimated price of the laptop with the above mentioned specs is ₹"+str(round(op[0]))+".")
# Out:
# The estimated price of the laptop with the above mentioned specs is ₹124645.

# %%
# Deployment

# %%
# Streamlit
# Streamlit cloud
# GitHub

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
pickle.dump(df,open('df.pkl','wb'))

# %%
# !pip install streamlit --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 75.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 96.0 MB/s eta 0:00:00

# %%
# %%writefile abc.txt
# This is a test file
# Out:
# Writing abc.txt

# %%
# %%writefile laptop_app.py
import streamlit as st
import pickle
df=pickle.load(open('df.pkl','rb'))
pipe=pickle.load(open('pipe.pkl','rb'))
st.title("Laptop Price Predictor App")
st.text("This app is using only a select few laptops(around 1200 laptops), so it may not align exactly with real world data")

company=st.selectbox("Manufacturer of the Laptop",df['Company'].unique())
typename=st.radio("Type of the Laptop",df['TypeName'].unique(),horizontal=True)
cpu=st.selectbox("Processor",df['Cpu'].unique())
ram=st.pills("RAM on the system(in GB)",[4,8,12,16,24,32,64,128])
gpu=st.radio("Graphics Card",df['Gpu'].unique(),index=1,horizontal=True)
os=st.selectbox("Operating System",df['OpSys'].unique(),index=2)
weight=st.slider("Weight of the laptop(in kg)",min_value=4.8,step=0.1,value=2.1)
touchscreen=st.pills("Does the laptop have an touchscreen?",['Yes','No'])
ips=st.pills("Does the laptop have an IPS display?",['Yes','No'])
cpu_speed=st.slider("Clock Speed pf CPU(in GHz)",min_value=0.9,max_value=3.6,step=0.1,value=2.3)
hdd=st.pills("Hard disk size on the system(in GB). If only SSD is present, select this is as 0",
             [0,512,1024,2000])
ssd=st.pills("SSD storage on the system(in GB).",[0,256,512,1024,2000])
screen_size=st.slider("Screen size(measured diagonally, in inches)",min_value=10.0,max_value=18.4,value=15.6,step=0.1)
screen_resolution=st.selectbox("Laptop Screen Resolution (in pixels)",
 ["2560x1600","1440x900","1920x1080","2880x1800","1366x768","2304x1440","3200x1800","1920x1200","2256x1504",
  "3840x2160","2160x1440","2560x1440","1600x900","2736x1824","2400x1600"],index=2)

if st.button("PREDICT PRICE"):
    if touchscreen == 'Yes':
        touchscreen=1
    else:
        touchscreen=0
    if ips == 'Yes':
        ips=1
    else:
        ips=0
    X_res=int(screen_resolution.split('x')[0])
    Y_res=int(screen_resolution.split('x')[1])
    ppi = ((X_res**2)+(Y_res**2))**0.5/screen_size
    query=[[company,typename,cpu,ram,gpu,os,weight,touchscreen,ips,cpu_speed,hdd,ssd,ppi]]
    op=pipe.predict(query)
    st.subheader("The estimated price of the laptop with the above mentioned specs is ₹"+str(int(round(op[0],-2)))+".")
# Out:
# Writing laptop_app.py

# %%
df.sample()
# Out:
#     Company  TypeName            Cpu  Ram      Gpu                   OpSys  \
# 385    Dell  Notebook  Intel Core i7    8  AMD GPU  Linux/Chrome OS/Others
#
#      Weight  Price  Touchscreen  IPS  Cpu_Speed  HDD  SSD     ppi
# 385    2.33  80600            0    0        2.7    0  256  174.06

# %%
df['Cpu_Speed'].describe()
# Out:
# count    1224.000000
# mean        2.311683
# std         0.495780
# min         0.900000
# 25%         2.000000
# 50%         2.500000
# 75%         2.700000
# max         3.600000
# Name: Cpu_Speed, dtype: float64

# %%
! streamlit run laptop_app.py & npx localtunnel --port 8501
# Out:
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
# ⠙⠹⠸⠼⠴
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.16.176.107:8501
#
# ⠦⠧⠇⠏⠋Need to install the following packages:
# localtunnel@2.0.2
# Ok to proceed? (y) y
#
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋your url is: https://rare-walls-act.loca.lt
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ────────────────────────── Traceback (most recent call last) ───────────────────────────
#   /usr/local/lib/python3.12/dist-packages/streamlit/runtime/scriptrunner/exec_code.py:
#   128 in exec_func_with_error_handling
#
#   /usr/local/lib/python3.12/dist-packages/streamlit/runtime/scriptrunner/script_runner
#   .py:669 in code_to_exec
#
#   /content/laptop_app.py:39 in <module>
#
#     36 │   Y_res=int(screen_resolution.split('x')[1])
#     37 │   ppi = ((X_res**2)+(Y_res**2))**0.5/screen_size
#     38 │   query=[[company,typename,cpu,ram,gpu,os,weight,touchscreen,ips,cpu_speed,hd
#   ❱ 39 │   op=pipe.predict(query)
#     40 │   st.subheader("The estimated price of the laptop with the above mentioned sp
#     41
#
#   /usr/local/lib/python3.12/dist-packages/sklearn/pipeline.py:788 in predict
#
#      785 │   │   │   if not _routing_enabled():
#      786 │   │   │   │   for _, name, transform in self._iter(with_final=False):
#      787 │   │   │   │   │   Xt = transform.transform(Xt)
#   ❱  788 │   │   │   │   return self.steps[-1][1].predict(Xt, **params)
#      789 │   │   │
#      790 │   │   │   # metadata routing enabled
#      791 │   │   │   routed_params = process_routing(self, "predict", **params)
#
#   /usr/local/lib/python3.12/dist-packages/sklearn/ensemble/_gb.py:2144 in predict
#
#     2141 │   │   y : ndarray of shape (n_samples,)
#     2142 │   │   │   The predicted values.
#     2143 │   │   """
#   ❱ 2144 │   │   X = validate_data(
#     2145 │   │   │   self, X, dtype=DTYPE, order="C", accept_sparse="csr", reset=False
#     2146 │   │   )
#     2147 │   │   # In regression we can directly return the raw value from the trees.
#
#   /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2944 in
#   validate_data
#
#     2941 │   │   else:
#     2942 │   │   │   out = X, y
#     2943 │   elif not no_val_X and no_val_y:
#   ❱ 2944 │   │   out = check_array(X, input_name="X", **check_params)
#     2945 │   elif no_val_X and not no_val_y:
#     2946 │   │   out = _check_y(y, **check_params)
#     2947 │   else:
#
#   /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1107 in
#   check_array
#
#     1104 │   │   │   )
#     1105 │   │
#     1106 │   │   if ensure_all_finite:
#   ❱ 1107 │   │   │   _assert_all_finite(
#     1108 │   │   │   │   array,
#     1109 │   │   │   │   input_name=input_name,
#     1110 │   │   │   │   estimator_name=estimator_name,
#
#   /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:120 in
#   _assert_all_finite
#
#      117 │   if first_pass_isfinite:
#      118 │   │   return
#      119 │
#   ❱  120 │   _assert_all_finite_element_wise(
#      121 │   │   X,
#      122 │   │   xp=xp,
#      123 │   │   allow_nan=allow_nan,
#
#   /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:169 in
#   _assert_all_finite_element_wise
#
#      166 │   │   │   │   " https://scikit-learn.org/stable/modules/impute.html"
#      167 │   │   │   │   "#estimators-that-handle-nan-values"
#      168 │   │   │   )
#   ❱  169 │   │   raise ValueError(msg_err)
#      170
#      171
#      172 def assert_all_finite(
# ────────────────────────────────────────────────────────────────────────────────────────
# ValueError: Input X contains NaN.
# GradientBoostingRegressor does not accept missing values encoded as NaN natively. For
# supervised learning, you might want to consider
# sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing
# values encoded as NaNs natively. Alternatively, it is possible to preprocess the data,
# for instance by using an imputer transformer in a pipeline or drop samples with missing
# values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of
# all estimators that handle NaN values at the following page:
# https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
#   Stopping...
# ^C
